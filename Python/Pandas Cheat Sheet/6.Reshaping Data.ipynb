# %% [markdown]
# # Pandas Cheat Sheet_6
# * cheat sheet: https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf
# * source: [인프런_단두장의 문서로 데이터 분석과 시각화 뽀개기 by 박조은강사님](https://www.inflearn.com/course/%ED%8C%90%EB%8B%A4%EC%8A%A4-pandas/)

# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset("mpg")
df.shape
# Out:
# (398, 9)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ## Reshaping Data_Arranging
# ### sort_values
# 기능: 값으로 정렬
#
# **parameters**
# * by : 축으로 지정할 column|Index
# * axis=0 : 값 비교 단위 (행(0)|열(1) 설정
# * ascending=True : 정렬방법 - 오름차순 / 내림차순 (False)
# * inplace=False : 정렬결과 원본 바로 적용 여부
# * na_position='last': 결측치 순서 설정

# %%
df.sort_values?

# %%
df.sort_values('mpg') #mpg 컬럼 안의 값의 오름차순으로 정렬
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28    9.0          8         304.0       193.0    4732          18.5
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 124  11.0          8         350.0       180.0    3664          11.0
# ..    ...        ...           ...         ...     ...           ...
# 326  43.4          4          90.0        48.0    2335          23.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 325  44.3          4          90.0        48.0    2085          21.7
# 329  44.6          4          91.0        67.0    1850          13.8
# 322  46.6          4          86.0        65.0    2110          17.9
#
#      model_year  origin                  name
# 28           70     usa              hi 1200d
# ...

# %%
df.sort_values('mpg', ascending=False) #내림차순 정렬
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
# 329  44.6          4          91.0        67.0    1850          13.8
# 325  44.3          4          90.0        48.0    2085          21.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
# ..    ...        ...           ...         ...     ...           ...
# 103  11.0          8         400.0       150.0    4997          14.0
# 67   11.0          8         429.0       208.0    4633          11.0
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 28    9.0          8         304.0       193.0    4732          18.5
#
#      model_year  origin                  name
# 322          80   japan             mazda glc
# ...

# %% [markdown]
# ### rename
#
# column/index의 이름변경

# %%
df=df.rename(columns = {'model_year' : 'year'}) # 변경내용 저장을 위해서는 df에 다시 저장해주어야 한다.
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 393  27.0          4         140.0        86.0    2790          15.6    82
# 394  44.0          4          97.0        52.0    2130          24.6    82
# 395  32.0          4         135.0        84.0    2295          11.6    82
# 396  28.0          4         120.0        79.0    2625          18.6    82
# 397  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %% [markdown]
# ### sort_index
# 기능 : index 목록을 기준으로 정렬

# %%
df.sort_index()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 393  27.0          4         140.0        86.0    2790          15.6    82
# 394  44.0          4          97.0        52.0    2130          24.6    82
# 395  32.0          4         135.0        84.0    2295          11.6    82
# 396  28.0          4         120.0        79.0    2625          18.6    82
# 397  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %% [markdown]
# ### reset_index
# 기능: 인덱스가 별도로 없을 때, 인덱스를 새로 만듬 (컬럼형태로 새로 생김)

# %%
df.reset_index()
# Out:
#      index   mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0        0  18.0          8         307.0       130.0    3504          12.0
# 1        1  15.0          8         350.0       165.0    3693          11.5
# 2        2  18.0          8         318.0       150.0    3436          11.0
# 3        3  16.0          8         304.0       150.0    3433          12.0
# 4        4  17.0          8         302.0       140.0    3449          10.5
# ..     ...   ...        ...           ...         ...     ...           ...
# 393    393  27.0          4         140.0        86.0    2790          15.6
# 394    394  44.0          4          97.0        52.0    2130          24.6
# 395    395  32.0          4         135.0        84.0    2295          11.6
# 396    396  28.0          4         120.0        79.0    2625          18.6
# 397    397  31.0          4         119.0        82.0    2720          19.4
#
#      year  origin                       name
# ...

# %% [markdown]
# ### drop
# 특정 column이나 index를 삭제함

# %%
df.drop(columns=['mpg','year','name'])
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  origin
# 0            8         307.0       130.0    3504          12.0     usa
# 1            8         350.0       165.0    3693          11.5     usa
# 2            8         318.0       150.0    3436          11.0     usa
# 3            8         304.0       150.0    3433          12.0     usa
# 4            8         302.0       140.0    3449          10.5     usa
# ..         ...           ...         ...     ...           ...     ...
# 393          4         140.0        86.0    2790          15.6     usa
# 394          4          97.0        52.0    2130          24.6  europe
# 395          4         135.0        84.0    2295          11.6     usa
# 396          4         120.0        79.0    2625          18.6     usa
# 397          4         119.0        82.0    2720          19.4     usa
#
# [398 rows x 6 columns]

# %% [markdown]
# ## Reshaping Data_Tidy Data (Layout chaning)

# %% [markdown]
# ### melt
# : Column을 Row로 gather
#
# ```python
# pd.melt(
#     frame: 'DataFrame',
#     id_vars=None,                         # 기준 열
#     value_vars=None,                     #melt할 열
#     var_name=None,            #value_vars 목록 이름
#     value_name='value',  # value_vars별로 나타낼 값
#     col_level=None,
#     ignore_index: bool = True,
# ) -> 'DataFrame
# ```

# %%
df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})
df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
pd.melt(df, id_vars=['A'], value_vars=['B'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5

# %%
pd.melt(df, id_vars=['A'], value_vars=['B','C'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %%
pd.melt(df, value_vars=['A','B','C'])
# Out:
#   variable value
# 0        A     a
# 1        A     b
# 2        A     c
# 3        B     1
# 4        B     3
# 5        B     5
# 6        C     2
# 7        C     4
# 8        C     6

# %%
pd.melt(df, value_vars=['A','B','C']).rename(columns={
'variabe' : 'var',
'value': 'val'})
# Out:
#   variable val
# 0        A   a
# 1        A   b
# 2        A   c
# 3        B   1
# 4        B   3
# 5        B   5
# 6        C   2
# 7        C   4
# 8        C   6

# %% [markdown]
# ### pivot
# : row값을 column으로 spread
# ```python
# df.pivot(index=None,   #기준 index로 삼을 column
#          columns=None, # row값을 columns화 할 column
#          values=None   # 나타낼 값
# ) -> 'DataFrame'
# ```

# %%
df2 = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two','two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df2
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df2.pivot(index='foo', columns='bar', values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df3=df2.pivot(index='foo', columns='bar', values='baz').reset_index()
df3
# Out:
# bar  foo  A  B  C
# 0    one  1  2  3
# 1    two  4  5  6

# %% [markdown]
# ### 다시 원래데이터로 녹이기

# %%
df3.melt(
    id_vars='foo', 
    value_vars=['A','B','C']).sort_values(
    ['foo','bar']).rename(columns = {'value':'baz'})
# Out:
#    foo bar  baz
# 0  one   A    1
# 2  one   B    2
# 4  one   C    3
# 1  two   A    4
# 3  two   B    5
# 5  two   C    6

# %% [markdown]
# ## Concat : 시리즈, 프레임 합치기
# ```python
# pd.concat(
#     objs: Union[Iterable[~FrameOrSeries], Mapping[Union[Hashable, NoneType], ~FrameOrSeries]],
#     axis=0,
#     join='outer',
#     ignore_index: bool = False,
#     keys=None,
#     levels=None,
#     names=None,
#     verify_integrity: bool = False,
#     sort: bool = False,
#     copy: bool = True,
# ) -> Union[ForwardRef('DataFrame'), ForwardRef('Series')]
# ```

# %% [markdown]
# ### Series Concat

# %%
s1=pd.Series(['a','b'])
s1
# Out:
# 0    a
# 1    b
# dtype: object

# %%
s2=pd.Series(['c','d'])
s2
# Out:
# 0    c
# 1    d
# dtype: object

# %%
pd.concat([s1,s2]) #행방향으로 시리즈 합치기. 기존 인덱스명이 살아있다.
# Out:
# 0    a
# 1    b
# 0    c
# 1    d
# dtype: object

# %%
pd.concat([s1,s2], ignore_index=True) #인덱스명 재설정
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
pd.concat([s1,s2], keys=['s1','s2'], names=['Series name', 'Row ID'])
# Out:
# Series name  Row ID
# s1           0         a
#              1         b
# s2           0         c
#              1         d
# dtype: object

# %% [markdown]
# ### Data Frame Concat

# %%
pd.concat?

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                    columns=['letter', 'number'])
df1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter', 'number'])
df2
# Out:
#   letter  number
# 0      c       3
# 1      d       4

# %%
df3 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']],
                   columns=['letter', 'number', 'animal'])
df3
# Out:
#   letter  number animal
# 0      c       3    cat
# 1      d       4    dog

# %%
pd.concat([df1,df3]) #데이터형태가 다른 자료들 결합 가능
# Out:
#   letter  number animal
# 0      a       1    NaN
# 1      b       2    NaN
# 0      c       3    cat
# 1      d       4    dog

# %%
pd.concat([df1,df3], join='inner') #join 파라미터를 설정하면 공통 열 만 행결합
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
df4 = pd.DataFrame([['bird', 'polly'], ['monkey', 'george']],
                   columns=['animal', 'name'])
df4
# Out:
#    animal    name
# 0    bird   polly
# 1  monkey  george

# %%
df5 = pd.DataFrame([1], index=['a'])
df5
# Out:
#    0
# a  1

# %%
df6 = pd.DataFrame([2], index=['a'])
df6
# Out:
#    0
# a  2

# %%
pd.concat([df5, df6], verify_integrity=True) # 중복된 index가 있는지 확인. 있으면 error남
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-effc43a713f2> in <module>
# ----> 1 pd.concat([df5, df6], verify_integrity=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     452         self.copy = copy
#     453
# --> 454         self.new_axes = self._get_new_axes()
#     455
#     456     def get_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in _get_new_axes(self)
# ...
